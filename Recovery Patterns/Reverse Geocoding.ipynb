# %%
from geopy.geocoders import Nominatim
import pandas as pd
import numpy as np
data = pd.read_csv("Nepal_GeoData.csv",sep=",")

# %%
df = data
df['neighborhood']=""
df['city']=""
df['state']=""
df['areadetail']=""
df['route']=""
df['zipcode']=""

# %%
df = df.loc[0:99999]

# %%
df.describe()
# Out:
#            d.id_str  d.favorite_count  d.in_reply_to_status_id_str  \
# count  1.000000e+05     100000.000000                 3.560500e+04
# mean   5.938533e+17          1.735170                 5.924660e+17
# std    1.643609e+16          8.185983                 1.900072e+16
# min    5.696492e+17          0.000000                 2.420247e+10
# 25%    5.810203e+17          0.000000                          NaN
# 50%    5.905514e+17          1.000000                          NaN
# 75%    6.049992e+17          1.000000                          NaN
# max    6.314649e+17       1434.000000                 6.314648e+17
#
#        d.retweet_count  d.user.id_str  d.in_reply_to_user_id_str  \
# count    100000.000000   1.000000e+05               3.956300e+04
# mean          0.729550   1.366362e+09               1.359464e+09
# std           6.321828   1.131682e+09               1.157186e+09
# min           0.000000   6.335230e+05               7.170000e+02
# ...

# %%
import requests
import urllib, json


def getaddress(latitude,longitude):
    sensor = 'true'
    base = "https://maps.googleapis.com/maps/api/geocode/json?"
    params = "latlng={lat},{lon}&key={apikey}".format(
        lat=latitude,
        lon=longitude,
        apikey = "AIzaSyAHFps2OwwfdySoSFv6SNCgNfC6tKiIWu0"
    )
    url = "{base}{params}".format(base=base, params=params)
    
    response = urllib.urlopen(url)
    data = json.loads(response.read())
    return data['results'][0]['address_components']

# %%
import requests
import urllib, json


def get_areaaddress(latitude,longitude):
    sensor = 'true'
    base = "http://photon.komoot.de/reverse?"
    params = "lat={lat}&lon={lon}".format(
        lat = latitude,
        lon = longitude
    )
    url = "{base}{params}".format(base=base, params=params)
    print url
    response = urllib.urlopen(url)
    data = json.loads(response.read())
    return data['features']

# %%
data.pincode.describe()
# Out:
# count     214556
# unique       937
# top
# freq      213429
# Name: pincode, dtype: object

# %%
data['pincode']=""
for row in data.index:
    data.loc[row,'pincode'] = get_areaaddress(data.loc[row,'geo.lat'],data.loc[row,'geo.lon'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-20d2388ac226> in <module>()
#       1 data['pincode']=""
#       2 for row in data.index:
# ----> 3     data.loc[row,'pincode'] = get_areaaddress(data.loc[row,'geo.lat'],data.loc[row,'geo.lon'])
#
# C:\Users\Snigdha\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in __setitem__(self, key, value)
#     130             key = com._apply_if_callable(key, self.obj)
#     131         indexer = self._get_setitem_indexer(key)
# --> 132         self._setitem_with_indexer(indexer, value)
#     133
#     134     def _has_valid_type(self, k, axis):
#
# C:\Users\Snigdha\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in _setitem_with_indexer(self, indexer, value)
#     525
#     526                     if len(labels) != len(value):
# ...

# %%
zones = ['Mechi','Koshi','Sagarmatha','Janakpur','Bagmati','Narayani','Gandaki','Lumbini','Dhaulagiri','Rapti','Karnali','Bheri','Seti','Mahakali']
get_areaaddress('Mechi')
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?components=administrative_area_2:Mechi|country:NP&key=AIzaSyAHFps2OwwfdySoSFv6SNCgNfC6tKiIWu0
# [{u'geometry': {u'location_type': u'APPROXIMATE', u'bounds': {u'northeast': {u'lat': 30.4469452, u'lng': 88.20152569999999}, u'southwest': {u'lat': 26.3479661, u'lng': 80.05846980000001}}, u'viewport': {u'northeast': {u'lat': 30.4469452, u'lng': 88.20152569999999}, u'southwest': {u'lat': 26.3479661, u'lng': 80.05846980000001}}, u'location': {u'lat': 28.394857, u'lng': 84.12400799999999}}, u'address_components': [{u'long_name': u'Nepal', u'types': [u'country', u'political'], u'short_name': u'NP'}], u'place_id': u'ChIJz2gufcfolTkR3obM0LyaojQ', u'formatted_address': u'Nepal', u'types': [u'country', u'political']}]

# %%
def elementextract(addressjson,address_type):
        i = 0
        while True:
            if addressjson[i]["types"][0]==address_type:
                return addressjson[i]["long_name"]
            else:
                i = i+1

# %%
with open("citycoor.csv",'a') as filecoor:
    for row in df.index:
        if (not(df.loc[row,'geo.lat'] is None or df.loc[row,'geo.lon'] is None)):
            try:
                addressset = getaddress(df.loc[row,'geo.lat'],df.loc[row,'geo.lon'])
            except:
                break
            try:
                t = encodeelementextract(addressset,'neighborhood')
                df.loc[row,'neighborhood'] =t
            except:
                df.loc[row,'neighborhood']=""
            try:
                t = elementextract(addressset,"locality")
                df.loc[row,'city'] =t
            except:
                df.loc[row,'city']=""
            try:
                t = elementextract(addressset,"administrative_area_level_2")
                df.loc[row,'areadetail'] =t
            except:
                df.loc[row,'areadetail']=""
            try:
                t = elementextract(addressset,"route")
                df.loc[row,'route'] =t
            except:
                df.loc[row,'route']=""
            try:
                t = elementextract(addressset,"administrative_area_level_1")
                df.loc[row,'state'] =t
            except:
                df.loc[row,'state']=""
            try:
                t = elementextract(addressset,"postal_code")
                df.loc[row,'zipcode'] =t
            except:
                df.loc[row,'zipcode']=""

# %%
df.head(10)
# Out:
#   d.favorited      d.id_str  d.favorite_count  d.in_reply_to_status_id_str  \
# 0       False  5.891146e+17                 3                          NaN
# 1       False  5.894273e+17                 3                          NaN
# 2       False  5.897475e+17                 0                 5.897471e+17
# 3       False  5.896474e+17                 1                 5.896472e+17
# 4       False  5.890443e+17                 0                 5.890430e+17
# 5       False  5.889535e+17                 1                 5.889519e+17
# 6       False  5.887357e+17                 1                 5.887351e+17
# 7       False  5.888787e+17                 0                 5.888739e+17
# 8       False  5.890526e+17                 1                          NaN
# 9       False  5.886661e+17                 1                 5.886660e+17
#
#   d.retweeted  d.retweet_count  \
# 0       False                1
# 1       False                0
# 2       False                0
# ...

# %%
import sys  

reload(sys)  
sys.setdefaultencoding('ascii')

# %%
df.to_csv("setonelocdf.csv")

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
location = geolocator.reverse("27.6988, 85.3774")
location.address
# Out:
# u'F89, \u0915\u093e\u0920\u092e\u093e\u0921\u094c\u0902, \u092c\u093e\u0917\u092e\u0924\u0940 \u0905\u091e\u094d\u091a\u0932, \u092e\u0927\u094d\u092f\u092e\u093e\u091e\u094d\u091a\u0932 \u0935\u093f\u0915\u093e\u0938 \u0915\u094d\u0937\u0947\u0924\u094d\u0930, 9771, \u0928\u0947\u092a\u093e\u0932'

# %%
get_address(27.6888,85.3774)
# Out:
# 2               Kathmandu
# 4               Kathmandu
# 5               Kathmandu
# 9                   Patan
# 10        Siddharthanagar
# 13              Kathmandu
# 14           Barbhanjyang
# 16              Kathmandu
# 17                Baglung
# 18              Kathmandu
# 19               Ghandruk
# 20               Katahari
# 21              Kathmandu
# 26              Bharatpur
# 28                Baglung
# 29             Ratnanagar
# 32             Biratnagar
# 34              Kathmandu
# 35              Kathmandu
# 36              Kathmandu
# 49              Bharatpur
# 51                 Katari
# 52              Kathmandu
# 54              Dandagaun
# 58              Kathmandu
# 61              Kathmandu
# 68              Kathmandu
# 69              Bharatpur
# 71              Bharatpur
# 79              Kathmandu
#                ...
# 183645
# 183646
# 183647
# 183648
# 183649
# 183650
# 183651
# 183652
# 183653
# 183655
# 183656
# 183661
# 183662
# 183663
# 183664
# ...

# %%
https://maps.googleapis.com/maps/api/geocode/json?
    
    components=administrative_area:{NP}|country:&key={key}
